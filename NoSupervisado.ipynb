# %% [markdown]
# <a href="https://colab.research.google.com/github/DiomedesIguax/BootCampTaller1/blob/17032024Titanic/NoSupervisado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **APRENDIZAJE NO SUPERVISADO**
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn import datasets
from sklearn.metrics import silhouette_score

wine = datasets.load_wine()
x = wine.data
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
kmeans=KMeans(n_clusters=3, random_state=42)
kmeans.fit(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=42)

# %%
labels = kmeans.predict(x)
silhouette_avg = silhouette_score(x, labels)
print("______________________________________________________________________________")
print("El puntaje promedio de silueta es:", silhouette_avg)
print("______________________________________________________________________________")
accuracy = np.mean(labels == wine.target)
print("La Precisión comparado con las etiquetas es:", accuracy)
print("______________________________________________________________________________")
# Out:
# ______________________________________________________________________________
# El puntaje promedio de silueta es: 0.2848589191898987
# ______________________________________________________________________________
# La Precisión comparado con las etiquetas es: 0.016853932584269662
# ______________________________________________________________________________
